# %%
# import libraries
import numpy as np 
import pandas as pd
from matplotlib import pyplot as plt

# %%
# import data

whole_data_df = pd.read_csv('whole_stock_data_with_added_features.csv')

# %%
whole_data_df.head(5)
# Out:
#   tickers   stock_name                  sector  \
# 0     MMM           3M             Industrials
# 1     AOS  A. O. Smith             Industrials
# 2     ABT       Abbott             Health Care
# 3    ABBV       AbbVie             Health Care
# 4     ACN    Accenture  Information Technology
#
#                      sub_industry              hq_location  date_added  \
# 0        Industrial Conglomerates    Saint Paul, Minnesota  1957-03-04
# 1               Building Products     Milwaukee, Wisconsin  2017-07-26
# 2           Health Care Equipment  North Chicago, Illinois  1957-03-04
# 3                 Pharmaceuticals  North Chicago, Illinois  2012-12-31
# 4  IT Consulting & Other Services          Dublin, Ireland  2011-07-06
#
#        cik      founded Revenue (2022) Revenue (2021)  ... Quick ratio (2012)  \
# 0    66740         1902         34,229         35,355  ...                  -
# 1    91142         1916        3,753.9        3,538.9  ...                  -
# ...

# %%
whole_data_df['tickers']
# Out:
# 0       MMM
# 1       AOS
# 2       ABT
# 3      ABBV
# 4       ACN
#        ...
# 498     YUM
# 499    ZBRA
# 500     ZBH
# 501    ZION
# 502     ZTS
# Name: tickers, Length: 503, dtype: object

# %%
(whole_data_df[whole_data_df['tickers'] == 'TSLA'])['Quick ratio (2013)']
# Out:
# 445    1.3396
# Name: Quick ratio (2013), dtype: object

# %%
# portfolio selection and optimization

# how best do we select the stocks to buy - Question 1
# how much shares should we buy - Question 2

# mean variance optimization is used for portfolio optimization and selection

# DEA - Portfolio Selection
# Mean-variance optimization - Portfolio Optimization
